# %% [markdown]
# <a href="https://colab.research.google.com/github/Arnabapun/Python-SRU/blob/main/python_workshop_day1__sru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***DAy1***

# %%
import keyword

# %%
print('Standard Keywords:', keyword.kwlist)
print('All available Keywords:', keyword.kwlist)
# Out:
# Standard Keywords: ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# All available Keywords: ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import keyword
print("standard keyword=",len(keyword.kwlist))
print("all keyword=", len(keyword.kwlist))
# Out:
# standard keyword= 35
# all keyword= 35

# %%
x=5
y= "python"
z=3.2
print(x)
print(y)
print(z)
# Out:
# 5
# python
# 3.2

# %%
print (type(x))
print (type(y))
print (type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
y1=2
print(y1)
print(type(y1))
# Out:
# 2
# <class 'int'>

# %%
y2=float(y1)
print(y2)
print(type(y2))
# Out:
# 2.0
# <class 'float'>

# %%
y3=str(y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'str'>

# %%
y1=int(2)
y2=float(2)
y3=str(2)
print(y1)
print(y2)
print(y3)
print (type(y1))
print (type(y2))
print (type(y3))
# Out:
# 2
# 2.0
# 2
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
c = -50
d=float(c)
print(type(d))
# Out:
# <class 'float'>

# %%
myname = "arnab"
mydepat = "Mech"
my_university = "sru"
my_location = "warangal"
print(myname)
print(mydepat)
print(my_university)
print(my_location)
# Out:
# arnab
# Mech
# sru
# warangal

# %%
a=input("enter value of a")
b=input("enter value of b")
a=int(a)
b=int(b)
print("===============")
print("sample calculator")
print("===============")
print("addtion=",a+b)
print("multiplication=",a*b)
print("sub=",a-b)
print("div=",a/b)
print("Rem=",a%b)
print("===============")
# Out:
# enter value of a20
# enter value of b10
# ===============
# sample calculator
# ===============
# addtion= 30
# multiplication= 200
# sub= 10
# div= 2.0
# Rem= 0
# ===============

# %% [markdown]
# **Day-2**

# %% [markdown]
# Precedence Operator

# %%
a=20
b=30
c=40
print ("value1=",a+b*c)
print ("value2=",(a+b)*c)
print ("value3=",c/a+(b*2)

# %% [markdown]
# logical operator

# %%
num1=10
num2=0
num=10
print("status" num1==num2 and num1==num3)
print("status" num1==num2 or num1==num3
print ("status" not num1>=num2)
