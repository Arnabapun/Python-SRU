# %% [markdown]
# <a href="https://colab.research.google.com/github/Arnabapun/Python-SRU/blob/main/python_workshop_day1__sru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***DAy1***

# %%
import keyword
# Out:
# Error in parse(text = input): <text>:1:8: unexpected symbol
# 1: import keyword
#            ^
# Traceback:

# %%
print('Standard Keywords:', keyword.kwlist)
print('All available Keywords:', keyword.kwlist)

# %%
import keyword
print("standard keyword=",len(keyword.kwlist))
print("all keyword=", len(keyword.kwlist))

# %%
x=5
y= "python"
z=3.2
print(x)
print(y)
print(z)

# %%
print (type(x))
print (type(y))
print (type(z))

# %%
y1=2
print(y1)
print(type(y1))

# %%
y2=float(y1)
print(y2)
print(type(y2))
# Out:
# Error in float(y1): could not find function "float"
# Traceback:

# %%
y3=str(y1)
print(y3)
print(type(y3))

# %%
y1=int(2)
y2=float(2)
y3=str(2)
print(y1)
print(y2)
print(y3)
print (type(y1))
print (type(y2))
print (type(y3))

# %%
c = -50
d=float(c)
print(type(d))

# %%
myname = "arnab"
mydepat = "Mech"
my_university = "sru"
my_location = "warangal"
print(myname)
print(mydepat)
print(my_university)
print(my_location)

# %%
a=input("enter value of a")
b=input("enter value of b")
a=int(a)
b=int(b)
print("===============")
print("sample calculator")
print("===============")
print("addtion=",a+b)
print("multiplication=",a*b)
print("sub=",a-b)
print("div=",a/b)
print("Rem=",a%b)
print("===============")

# %% [markdown]
# **Day-2**

# %% [markdown]
# Precedence Operator

# %%
a=20
b=30
c=40
print ("value1=",a+b*c)
print ("value2=",(a+b)*c)
print ("value3=",c/a+(b*2))
# Out:
# Error in print.default("value1=", a + b * c): invalid printing digits 1220
# Traceback:
#
# 1. print.default("value1=", a + b * c)
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "invalid printing digits 1220", base::quote(print.default("value1=",
#  .     a + b * c)))

# %% [markdown]
# logical operator

# %%
num1=10
num2=0
num=10
print("status" num1==num2 and num1==num3)
print("status" num1==num2 or num1==num3
print ("status" not num1>=num2)

# %% [markdown]
# assignment operator

# %%
num1=10
print("num1=",num1)
num2=num1
print("num2=",num2)
num2=20
print("num2=",num2)
num1+=num2
print("num1=",num1)
num1-=num2
print("num1=",num1)
num1*=num2
print("num1=",num1)
num1/=num2
print("num1=",num1)
num1%=num2
print("num1=",num1)
num1**=num2
print("num1=",num1)
num1//=num2
print("num1=",num1)
# Out:
# Error in parse(text = input): <text>:7:6: unexpected '='
# 6: print("num2=",num2)
# 7: num1+=
#         ^
# Traceback:

# %% [markdown]
# membership operator

# %%
students=["arnab","mukherjee"]
call_attendence=input("enter name")
print("status",call_attendence in students)
print("status",call_attendence not in students)
# Out:
# Error in parse(text = input): <text>:1:10: unexpected '['
# 1: students=[
#              ^
# Traceback:
